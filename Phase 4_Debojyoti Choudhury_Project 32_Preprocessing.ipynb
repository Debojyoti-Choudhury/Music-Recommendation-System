# %% [markdown]
# # Preprocessing of the Engineered Music Recommendation System Data
#
# **Submitted By:** Debojyoti Choudhury
#
# **Enrollment Number:** 40AIML137-21/2
#
# **Programme:** Diploma in AI and ML

# %% [markdown]
# The purpose of this notebook is to take the engineered data and preprocess them to create model-ready data.

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np                                  # for fast processing of tabular data
import pandas as pd                                 # data processing, CSV file I/O
import matplotlib.pyplot as plt                     # for data visualization
import seaborn as sns                               # for data visualization
import missingno                                    # for missing values visualization
import gc                                           # utility to free up the memory
from sklearn.preprocessing import StandardScaler    # for scaling the continuous features (standardizing) 
from sklearn.preprocessing import LabelEncoder      # for ordinal encoding of the categorical features 
from sklearn.preprocessing import MinMaxScaler      # for scaling the continuous features (min-max)

# %% [markdown]
# ## Read the engineered data

# %%
train_data = pd.read_csv("../Data/engineered_data/fe_train_data.csv.gz",compression='gzip')

# %%
test_data = pd.read_csv("../Data/engineered_data/fe_test_data.csv.gz", compression='gzip')

# %%
validation_data = pd.read_csv("../Data/engineered_data/fe_validation_data.csv.gz", compression='gzip')

# %%
train_data.head()
# Out:
#                                            msno  \
# 0  XyqTyQdDkjyvyVlF9HQEQMC7jpTt6uhfP0OElaBLckE=
# 1  LRvwVwXrRasztB6Ujf84G1E1M3PtDd6YfzLEsqTyuPo=
# 2  cRMes5eNsNChPwtNTj1+42usZO8yH69BkfC9px884yc=
# 3  LfhLJImWDCzeEf93gxaGT/IXqrvasxsZfOwVEhFmHw0=
# 4  Qyq0USrm2n4w9QqZr/Iuuv24IETeO6lgVEhNrs0HHwI=
#
#                                         song_id source_system_tab  \
# 0  IXP1a2o3NL8WU4WK1X0WJAKaSW+LgGRpPDn4Gt1HrV8=          discover
# 1  Ru7n8Xw2s8LGDsgDhyzWqCWQRWQW9KNPY9qMOFAf5x0=        my library
# 2  U8VgelI8G461f4FVJHnavdn4zx7XjmSFcNHZ3Hru3TU=        my library
# 3  JiY2ckGkra5KGchu3Rh6KPH9FL2J0tTmAB3pGyVi4BQ=          discover
# 4  uNNIh/p+Ucr+CQBnmtVQFi9OMloGqLgnHe1mXggKle4=            search
#
#      source_screen_name      source_type  city  bd          gender  \
# 0                others  online-playlist     2  28            male
# 1   Local playlist more    local-library     6   0  gender_missing
# 2   Local playlist more   local-playlist     6   0  gender_missing
# 3  Online playlist more  online-playlist     4  28            male
# 4                others           others     2  18          female
#
#    registered_via  registration_year  ...  song_year  member_song_count  \
# 0               9               2015  ...     2016.0                836
# 1               7               2013  ...     2016.0                389
# 2               7               2015  ...     2014.0                574
# 3               9               2007  ...     2016.0                425
# 4               4               2016  ...     2016.0                512
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0              57040                36465                37907
# 1              22567                15809                14400
# 2              22118                13466                14417
# 3              30798                27417                 9600
# 4             303616                  259              3178798
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count  \
# 0           3814444          4044643               6033          232548
# 1            329134          1864789               3488         2948104
# 2           3814444          4044643               5729         2948104
# 3           1266910          4044643               5820          232548
# 4            400596          1864789                249          124868
#
#    target
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#
# [5 rows x 42 columns]

# %%
validation_data.head()
# Out:
#                                            msno  \
# 0  0JLOaW5BdEelTbeS4ZJkuuDVr0NZPP+SG+zcxG/5qHo=
# 1  crR6QHSbA22COjylVND+tTjvk25uQPW7QXOLZo/PBMg=
# 2  FgE2jvvDEMVNw4QWqdLjyIpAkgDqtRWLevWP/FP9Gj8=
# 3  lPJxYddCsyfyph9qB1Ni/MSPrIWG+P4ADUPrCaJTs0M=
# 4  oxa+4yk7Lj3MvxFsP7wbTv4BGSKUxBQB7wHeqa0kWbM=
#
#                                         song_id source_system_tab  \
# 0  RMv6xdzVwGLCucAtyRR7h5LWV2HKXjJMAtEL2pBeBG4=        my library
# 1  OAkciD8vFKjj3vNPxHd+QiPxVYPfq+IGHQEMEGz/JxM=            search
# 2  6cl6GdZmBS8/qMJadkQJNM3c+NSiyXZmNIF3//QIDj8=        my library
# 3  ah833V1/nMgO+NNxtUpKn8m5bc9nCPi7AHV77/k1zNA=        my library
# 4  CkcGnJJYzv1tJVVEI0UlDBVuK1+5BH1Rk8PCuwcrkg8=        my library
#
#     source_screen_name     source_type  city  bd          gender  \
# 0  Local playlist more   local-library     6   0  gender_missing
# 1               others          others     0  27            male
# 2  Local playlist more   local-library     6   0  gender_missing
# 3  Local playlist more  local-playlist     1  26            male
# 4  Local playlist more   local-library     5  38          female
#
#    registered_via  registration_year  ...  song_year  member_song_count  \
# 0               9               2013  ...     2013.0                822
# 1               7               2012  ...     2004.0                463
# 2               4               2017  ...     2016.0                 54
# 3               3               2015  ...     2001.0                527
# 4               9               2011  ...     2016.0                498
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0              26759                  189              3178798
# 1              10197                  558              3178798
# 2              20731                  336                  411
# 3              13274                 1665              3178798
# 4              20617                 9873                 2341
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count  \
# 0           1266910            78621                143         2948104
# 1           3814444          4044643                 84          253065
# 2             59284           245136                247         2948104
# 3            400596           245136                 16          257869
# 4           3814444          1864789               2134           75166
#
#    target
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 42 columns]

# %%
test_data.head()
# Out:
#    id                                          msno  \
# 0   0  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 1   1  V8ruy7SGk7tDm3zA51DPpn6qutt+vmKMBKa21dp54uM=
# 2   2  /uQAlrAkaczV+nWCd2sPF2ekvXPRipV7q0l+gbLuxjw=
# 3   3  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
# 4   4  1a6oo/iXKatxQx4eS9zTVD+KlSVaAFbTIqVvwLC1Y0k=
#
#                                         song_id source_system_tab  \
# 0  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=        my library
# 1  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=        my library
# 2  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=          discover
# 3  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=             radio
# 4  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=             radio
#
#     source_screen_name    source_type  city  bd          gender  \
# 0               others  local-library     6   0  gender_missing
# 1  Local playlist more  local-library     6   0  gender_missing
# 2  Local playlist more         others     6   0  gender_missing
# 3  Local playlist more          radio     0  30            male
# 4               others          radio     0  30            male
#
#    registered_via  ...  registration_code  song_year  member_song_count  \
# 0               7  ...                UM7     2014.0                 17
# 1               7  ...                B67     2010.0                 17
# 2               4  ...                WP0     2010.0                  1
# 3               9  ...                AAN     2002.0                270
# 4               9  ...                O10     2011.0                270
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0               4009                  205              1224744
# 1              31571                25629                 1542
# 2                149                  125                  125
# 3                225                   40              1224744
# 4                 80                 1895              1224744
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count
# 0            384869          1311328                196         1046511
# 1           1248185          1311328               1479         1046511
# 2             56521            84227                  2         1046511
# 3           1248185           709024                 14           68238
# 4              2893           116856                  3           68238
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Check for missing values

# %% [markdown]
# Following columns have missing values

# %%
features_with_missing_values = train_data.columns[train_data.isna().any()].tolist()

features_with_missing_values
# Out:
# ['first_artist_name',
#  'first_lyricist',
#  'first_composer',
#  'country_code',
#  'registration_code',
#  'song_year']

# %%
def fill_missing_values(data):
    '''Function to fill missing values'''
    data['first_artist_name'].fillna('no_artist_name', inplace=True)
    data['first_lyricist'].fillna('no_lyricist', inplace=True)
    data['first_composer'].fillna('no_composer', inplace=True)
    data['country_code'].fillna('no_country_code', inplace=True)
    data['registration_code'].fillna('no_registration_code', inplace=True)
    return data

# %%
train_data = fill_missing_values(train_data)
test_data = fill_missing_values(test_data)
validation_data = fill_missing_values(validation_data)

# %%
rep_song_year = train_data['song_year'].median()

# %%
train_data['song_year'].fillna(rep_song_year, inplace=True)
test_data['song_year'].fillna(rep_song_year, inplace=True)
validation_data['song_year'].fillna(rep_song_year, inplace=True)

# %%
train_data.columns[train_data.isna().any()].tolist()
# Out:
# []

# %%
test_data.columns[test_data.isna().any()].tolist()
# Out:
# []

# %%
validation_data.columns[validation_data.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# The preprocessing shall be done in following way:
#
# - The continuous features shall be scaled using standard scaler. The standard scaler works like following
#   If $x$ is the feature whose mean value is $\bar{x}$ and standard deviation is $\sigma_x$ then the scaled feature will be:
#   $$x := \frac{x - \bar{x}}{\sigma_x}$$
#   The problem is if the features contains outliers or the data is highly skewed then this type of scaling will not work well.
#
# - If the continuous features are highly skewed then instead of standard scaler we can use min-max scaler
#   If $x$ is the feature whose minimum value is $x_{min}$ and maximum value is $x_{max}$ then the min-max scaler will work like following.
#   $$x := \frac{x - x_{min}}{x_{max} - x_{min}}$$
#   This ensures the scaled feature lies between 0 to 1
#
# - For categorical features we will use label encoder.

# %% [markdown]
# ### Selecting object type and numerical type features

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901934 entries, 0 to 5901933
# Data columns (total 42 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   msno                 object
#  1   song_id              object
#  2   source_system_tab    object
#  3   source_screen_name   object
#  4   source_type          object
#  5   city                 int64
#  6   bd                   int64
#  7   gender               object
#  8   registered_via       int64
#  9   registration_year    int64
#  10  registration_month   int64
#  11  registration_day     int64
#  12  expiration_year      int64
#  13  expiration_month     int64
#  14  expiration_day       int64
#  15  membership_days      int64
#  16  song_length          float64
#  17  first_genre_id       float64
#  18  second_genre_id      float64
#  19  third_genre_id       float64
#  20  genre_ids_count      float64
#  21  artist_name          object
#  22  language             int64
#  23  is_featured          int64
#  24  artist_count         int64
#  25  first_artist_name    object
#  26  lyricist_count       int64
#  27  first_lyricist       object
#  28  composer_count       int64
#  29  first_composer       object
#  30  country_code         object
#  31  registration_code    object
#  32  song_year            float64
#  33  member_song_count    int64
#  34  artist_song_count    int64
#  35  composer_song_count  int64
#  36  lyricist_song_count  int64
#  37  genre_song_count     int64
#  38  lang_song_count      int64
#  39  song_member_count    int64
#  40  age_song_count       int64
#  41  target               int64
# dtypes: float64(6), int64(24), object(12)
# memory usage: 1.8+ GB

# %%
object_type_features = train_data.select_dtypes(include=['object']).columns.to_list()

# %%
numerical_type_features = train_data.select_dtypes(exclude=['object']).columns.to_list()

# %% [markdown]
# ### Preprocessing the categorical features

# %% [markdown]
# There are 12 columns which are object types (categorical)

# %%
object_type_features
# Out:
# ['msno',
#  'song_id',
#  'source_system_tab',
#  'source_screen_name',
#  'source_type',
#  'gender',
#  'artist_name',
#  'first_artist_name',
#  'first_lyricist',
#  'first_composer',
#  'country_code',
#  'registration_code']

# %%
train_data[object_type_features].nunique()
# Out:
# msno                   30540
# song_id               324549
# source_system_tab          5
# source_screen_name         5
# source_type                7
# gender                     3
# artist_name            37773
# first_artist_name      36342
# first_lyricist         22843
# first_composer         45434
# country_code             105
# registration_code       6118
# dtype: int64

# %% [markdown]
# Here `song_id` is not important feature to consider because there is a huge cardinality.
#
# Hence, we shall consider following categorical features for label encoding.

# %%
cat_features = ['msno',
 'source_system_tab',
 'source_screen_name',
 'source_type',
 'gender',
 'artist_name',
 'first_artist_name',
 'first_lyricist',
 'first_composer',
 'country_code',
 'registration_code']

# %%
pd.set_option('mode.chained_assignment', None)
for feature in cat_features:
    le = LabelEncoder()
    print(f"Working on feature: {feature}")
    combined = train_data[feature].append(validation_data[feature])
    combined = set(combined.append(test_data[feature]))
    combined = np.array(list(combined))
    le = le.fit(combined)
    train_data[feature] = le.transform(train_data[feature].values.reshape(-1,1))
    validation_data[feature] = le.transform(validation_data[feature].values.reshape(-1,1))
    test_data[feature] = le.transform(test_data[feature].values.reshape(-1,1))
# Out:
# Working on feature: msno
# C:\Users\SouravKarmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Working on feature: source_system_tab
# Working on feature: source_screen_name
# Working on feature: source_type
# Working on feature: gender
# Working on feature: artist_name
# Working on feature: first_artist_name
# Working on feature: first_lyricist
# Working on feature: first_composer
# Working on feature: country_code
# Working on feature: registration_code

# %% [markdown]
# ### Preprocessing the numerical features

# %% [markdown]
# There are 30 columns which are numerical types

# %%
numerical_type_features
# Out:
# ['city',
#  'bd',
#  'registered_via',
#  'registration_year',
#  'registration_month',
#  'registration_day',
#  'expiration_year',
#  'expiration_month',
#  'expiration_day',
#  'membership_days',
#  'song_length',
#  'first_genre_id',
#  'second_genre_id',
#  'third_genre_id',
#  'genre_ids_count',
#  'language',
#  'is_featured',
#  'artist_count',
#  'lyricist_count',
#  'composer_count',
#  'song_year',
#  'member_song_count',
#  'artist_song_count',
#  'composer_song_count',
#  'lyricist_song_count',
#  'genre_song_count',
#  'lang_song_count',
#  'song_member_count',
#  'age_song_count',
#  'target']

# %%
train_data[numerical_type_features].nunique()
# Out:
# city                       7
# bd                        68
# registered_via             5
# registration_year         14
# registration_month        12
# registration_day          31
# expiration_year           18
# expiration_month          12
# expiration_day            31
# membership_days         4319
# song_length            55399
# first_genre_id           156
# second_genre_id           82
# third_genre_id            35
# genre_ids_count            8
# language                  11
# is_featured                2
# artist_count              10
# lyricist_count            23
# composer_count            27
# song_year                100
# member_song_count       1564
# artist_song_count       1619
# composer_song_count     1641
# lyricist_song_count     1324
# genre_song_count         125
# lang_song_count           11
# song_member_count       1798
# age_song_count            68
# target                     2
# dtype: int64

# %% [markdown]
# We shall use following features for scaling

# %%
numerical_features = ['bd',
 'registered_via',
 'membership_days',
 'song_length',
 'composer_count',
 'member_song_count',
 'artist_song_count',
 'composer_song_count',
 'lyricist_song_count',
 'genre_song_count',
 'lang_song_count',
 'song_member_count',
 'age_song_count']

# %%
for f in numerical_features:
    print(f"Working on feature: {f}")
    s = np.abs(train_data[f].skew())
    if s >= 1.0:
        encoder = MinMaxScaler()
    else:
        encoder = StandardScaler()
    encoder = encoder.fit(train_data[f].values.reshape(-1,1))
    train_data[f] = encoder.transform(train_data[f].values.reshape(-1,1))
    validation_data[f] = encoder.transform(validation_data[f].values.reshape(-1,1))
    test_data[f] = encoder.transform(test_data[f].values.reshape(-1,1))
# Out:
# Working on feature: bd
# Working on feature: registered_via
# Working on feature: membership_days
# Working on feature: song_length
# Working on feature: composer_count
# Working on feature: member_song_count
# Working on feature: artist_song_count
# Working on feature: composer_song_count
# Working on feature: lyricist_song_count
# Working on feature: genre_song_count
# Working on feature: lang_song_count
# Working on feature: song_member_count
# Working on feature: age_song_count

# %% [markdown]
# Dealing with year based features

# %%
for f in numerical_type_features:
    if 'year' in f:
        print(f"Working on feature: {f}")
        mid_year = train_data[f].median()
        train_data[f] = (train_data[f] - mid_year).astype('int')
        validation_data[f] = (validation_data[f] - mid_year).astype('int')
        test_data[f] = (test_data[f] - mid_year).astype('int')
# Out:
# Working on feature: registration_year
# Working on feature: expiration_year
# Working on feature: song_year

# %% [markdown]
# Dealing with Genre IDs

# %%
genres = set(train_data['first_genre_id'].astype('int')).union(set(train_data['second_genre_id'].astype('int'))).union(set(train_data['third_genre_id'].astype('int')))

# %%
genres = genres.union(set(validation_data['first_genre_id'].astype('int'))).union(set(validation_data['second_genre_id'].astype('int'))).union(set(validation_data['third_genre_id'].astype('int')))

# %%
genres = genres.union(set(test_data['first_genre_id'].astype('int'))).union(set(test_data['second_genre_id'].astype('int'))).union(set(test_data['third_genre_id'].astype('int')))

# %%
le = LabelEncoder()

# %%
le.fit(np.array(list(genres)))
# Out:
# LabelEncoder()

# %%
train_data['first_genre_id'] = le.transform(train_data['first_genre_id'].astype('int').values.reshape(-1,1))
train_data['second_genre_id'] = le.transform(train_data['second_genre_id'].astype('int').values.reshape(-1,1))
train_data['third_genre_id'] = le.transform(train_data['third_genre_id'].astype('int').values.reshape(-1,1))
# Out:
# C:\Users\SouravKarmakar\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
validation_data['first_genre_id'] = le.transform(validation_data['first_genre_id'].astype('int').values.reshape(-1,1))
validation_data['second_genre_id'] = le.transform(validation_data['second_genre_id'].astype('int').values.reshape(-1,1))
validation_data['third_genre_id'] = le.transform(validation_data['third_genre_id'].astype('int').values.reshape(-1,1))

# %%
test_data['first_genre_id'] = le.transform(test_data['first_genre_id'].astype('int').values.reshape(-1,1))
test_data['second_genre_id'] = le.transform(test_data['second_genre_id'].astype('int').values.reshape(-1,1))
test_data['third_genre_id'] = le.transform(test_data['third_genre_id'].astype('int').values.reshape(-1,1))

# %% [markdown]
# ## Saving the preprocessed (model-ready) data

# %%
pd.set_option('display.max_columns', 50)

# %%
train_data.head()
# Out:
#     msno                                       song_id  source_system_tab  \
# 0  19307  IXP1a2o3NL8WU4WK1X0WJAKaSW+LgGRpPDn4Gt1HrV8=                  0
# 1  12488  Ru7n8Xw2s8LGDsgDhyzWqCWQRWQW9KNPY9qMOFAf5x0=                  1
# 2  21774  U8VgelI8G461f4FVJHnavdn4zx7XjmSFcNHZ3Hru3TU=                  1
# 3  12590  JiY2ckGkra5KGchu3Rh6KPH9FL2J0tTmAB3pGyVi4BQ=                  0
# 4  15446  uNNIh/p+Ucr+CQBnmtVQFi9OMloGqLgnHe1mXggKle4=                  4
#
#    source_screen_name  source_type  city        bd  gender  registered_via  \
# 0                   4            3     2  0.691596       2        0.969300
# 1                   1            1     6 -1.107765       1        0.090447
# 2                   1            2     6 -1.107765       1        0.090447
# 3                   2            3     4  0.691596       2        0.969300
# 4                   4            4     2  0.048967       0       -1.227833
#
#    registration_year  registration_month  registration_day  expiration_year  \
# 0                  2                   4                10                0
# 1                  0                   1                 7                0
# 2                  2                  11                25                0
# 3                 -6                   4                 3                0
# 4                  3                  11                 5                0
#
#    expiration_month  expiration_day  membership_days  song_length  \
# 0                 9              30        -0.641538     0.259599
# 1                 9              30         0.087540     0.243548
# 2                 9              20        -0.853263     0.312308
# 3                10              11         1.962944     0.264823
# 4                 9               7        -1.171294     0.167287
#
#    first_genre_id  second_genre_id  third_genre_id  genre_ids_count  \
# 0              41                0               0              1.0
# 1             126                0               0              1.0
# 2              41                0               0              1.0
# 3              40                0               0              1.0
# 4              77                0               0              1.0
#
#    artist_name  language  is_featured  artist_count  first_artist_name  \
# 0        44623         3            0             1              42871
# 1         5760         0            0             1               5377
# 2        21606         3            0             1              20590
# 3        41281         3            0             1              39550
# 4        36867         0            0             1              35217
#
#    lyricist_count  first_lyricist  composer_count  first_composer  \
# 0               1           12786        0.009259           33528
# 1               1            2380        0.009259            6342
# 2               1           10369        0.009259           27036
# 3               1           23823        0.018519           47315
# 4               0           17278        0.009259           34859
#
#    country_code  registration_code  song_year  member_song_count  \
# 0           101               1738          2           0.143520
# 1            33               2063          2           0.066690
# 2           101               4316          0           0.098487
# 3           101               1722          2           0.072877
# 4           107               5401          2           0.087831
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0           0.187866             0.021760            -0.858809
# 1           0.074324             0.009434            -0.873839
# 2           0.072846             0.008035            -0.873829
# 3           0.101434             0.016361            -0.876909
# 4           1.000000             0.000154             1.149534
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count  \
# 0          0.943030         0.856465           0.431721       -0.773667
# 1         -1.162382        -0.612357           0.249571        1.224460
# 2          0.943030         0.856465           0.409963        1.224460
# 3         -0.595889         0.856465           0.416476       -0.773667
# 4         -1.119213        -0.612357           0.017750       -0.852899
#
#    target
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
validation_data.head()
# Out:
#     msno                                       song_id  source_system_tab  \
# 0   1218  RMv6xdzVwGLCucAtyRR7h5LWV2HKXjJMAtEL2pBeBG4=                  1
# 1  21990  OAkciD8vFKjj3vNPxHd+QiPxVYPfq+IGHQEMEGz/JxM=                  4
# 2   9393  6cl6GdZmBS8/qMJadkQJNM3c+NSiyXZmNIF3//QIDj8=                  1
# 3  26565  ah833V1/nMgO+NNxtUpKn8m5bc9nCPi7AHV77/k1zNA=                  1
# 4  28486  CkcGnJJYzv1tJVVEI0UlDBVuK1+5BH1Rk8PCuwcrkg8=                  1
#
#    source_screen_name  source_type  city        bd  gender  registered_via  \
# 0                   1            1     6 -1.107765       1        0.969300
# 1                   4            4     0  0.627333       2        0.090447
# 2                   1            1     6 -1.107765       1       -1.227833
# 3                   1            2     1  0.563070       2       -1.667259
# 4                   1            1     5  1.334224       0        0.969300
#
#    registration_year  registration_month  registration_day  expiration_year  \
# 0                  0                   4                13                0
# 1                 -1                   1                13                0
# 2                  4                   1                22                0
# 3                  2                   4                15                0
# 4                 -2                   2                17                0
#
#    expiration_month  expiration_day  membership_days  song_length  \
# 0                 9              22        -0.004592     0.294378
# 1                10               6         0.411771     0.230341
# 2                 7               9        -1.293545     0.223491
# 3                10               1        -0.645082     0.268490
# 4                 9               8         0.679306     0.234347
#
#    first_genre_id  second_genre_id  third_genre_id  genre_ids_count  \
# 0              40                0               0              1.0
# 1              41                0               0              1.0
# 2              37                0               0              1.0
# 3              77                0               0              1.0
# 4              41                0               0              1.0
#
#    artist_name  language  is_featured  artist_count  first_artist_name  \
# 0        41698         6            0             1              39968
# 1        43280         3            0             1              41543
# 2        10504         4            0             1               9902
# 3        39782         4            0             1              38055
# 4        30813         0            0             1              29401
#
#    lyricist_count  first_lyricist  composer_count  first_composer  \
# 0               0           17278        0.009259           32661
# 1               0           17278        0.009259           39959
# 2               2             782        0.037037            2356
# 3               0           17278        0.009259           45549
# 4               3            8695        0.027778           23368
#
#    country_code  registration_code  song_year  member_song_count  \
# 0           101               6234         -1           0.141114
# 1           101               1773        -10           0.079409
# 2            54               2214          2           0.009110
# 3            54               6064        -13           0.090409
# 4           107               5603          2           0.085425
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0           0.088131             0.000112             1.149534
# 1           0.033582             0.000332             1.149534
# 2           0.068277             0.000200            -0.882784
# 3           0.043717             0.000993             1.149534
# 4           0.067902             0.005891            -0.881550
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count  \
# 0         -0.595889        -1.815906           0.010163        1.224460
# 1          0.943030         0.856465           0.005940       -0.758571
# 2         -1.325394        -1.703706           0.017607        1.224460
# 3         -1.119213        -1.703706           0.001074       -0.755036
# 4          0.943030        -0.612357           0.152662       -0.889470
#
#    target
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1

# %%
test_data.head()
# Out:
#    id   msno                                       song_id  source_system_tab  \
# 0   0  17724  WmHKgKMlp1lQMecNdNvDMkvIycZYHnFwDT72I5sIssc=                  1
# 1   1  17724  y/rsZ9DC7FwK5F2PK2D5mj+aOBUJAjuu3dZ14NgE0vM=                  1
# 2   2    977  8eZLFOdGVdXBSqoAv5nsLigeH2BvKXzTQYtUM53I0k4=                  0
# 3   3   1878  ztCf8thYsS4YN3GcIL/bvoxLm/T5mYBVKOO4C9NiVfQ=                  3
# 4   4   1878  MKVMpslKcQhMaFEgcEQhEfi5+RZhMYlU3eRDpySrH8Y=                  3
#
#    source_screen_name  source_type  city        bd  gender  registered_via  \
# 0                   4            1     6 -1.107765       1        0.090447
# 1                   1            1     6 -1.107765       1        0.090447
# 2                   1            4     6 -1.107765       1       -1.227833
# 3                   1            5     0  0.820121       2        0.969300
# 4                   4            5     0  0.820121       2        0.969300
#
#    registration_year  registration_month  registration_day  expiration_year  \
# 0                  3                   2                19                0
# 1                  3                   2                19                0
# 2                  3                  11                17               -1
# 3                 -6                   7                25                0
# 4                 -6                   7                25                0
#
#    expiration_month  expiration_day  membership_days  song_length  \
# 0                 9              18        -0.931221     0.249033
# 1                 9              18        -0.931221     0.356078
# 2                11              24        -1.436171     0.350999
# 3                 4              30         1.717556     0.316900
# 4                 4              30         1.717556     0.219544
#
#    first_genre_id  second_genre_id  third_genre_id  genre_ids_count  \
# 0              40                0               0              1.0
# 1              41                0               0              1.0
# 2             140                0               0              1.0
# 3              41                0               0              1.0
# 4              72                0               0              1.0
#
#    artist_name  language  is_featured  artist_count  first_artist_name  \
# 0        42813         3            0             1              41079
# 1        42633         3            0             1              40900
# 2        38492         4            0             1              36789
# 3        36423         0            0             1              34785
# 4        38298         1            0             1              36603
#
#    lyricist_count  first_lyricist  composer_count  first_composer  \
# 0               0           17278        0.009259           33433
# 1               2           19800        0.009259           49460
# 2               1           16782        0.009259           43693
# 3               0           17278        0.037037           39854
# 4               0           17278        0.009259           30641
#
#    country_code  registration_code  song_year  member_song_count  \
# 0           101               6234          0           0.002750
# 1           101               2221         -4           0.002750
# 2            54               6585         -4           0.000000
# 3            33               1815        -12           0.046236
# 4            51               5056         -3           0.046236
#
#    artist_song_count  composer_song_count  lyricist_song_count  \
# 0           0.013201             0.000122            -0.099924
# 1           0.103980             0.015294            -0.882061
# 2           0.000487             0.000074            -0.882967
# 3           0.000738             0.000023            -0.099924
# 4           0.000260             0.001130            -0.099924
#
#    genre_song_count  lang_song_count  song_member_count  age_song_count
# 0         -1.128714        -0.985288           0.013956       -0.174747
# 1         -0.607200        -0.985288           0.105783       -0.174747
# 2         -1.327063        -1.812129           0.000072       -0.174747
# 3         -0.607200        -1.391130           0.000930       -0.894568
# 4         -1.359458        -1.790143           0.000143       -0.894568

# %%
train_data.shape, validation_data.shape, test_data.shape
# Out:
# ((5901934, 42), (1475484, 42), (2556790, 42))

# %%
train_data.to_csv("../Data/preprocessed_data/mrd_train_data.csv.gz", sep=',', index=False, compression='gzip')
test_data.to_csv("../Data/preprocessed_data/mrd_test_data.csv.gz", sep=',', index=False, compression='gzip')
validation_data.to_csv("../Data/preprocessed_data/mrd_validation_data.csv.gz", sep=',', index=False, compression='gzip')

# %% [markdown]
# ## Sample the dataset

# %% [markdown]
# As the dataset is quite huge. As the system configuration is not enough to handle this huge data we will sample the dataset and will use that sampled data to train our models.
#
# We will use 20% data from train and validation set.

# %%
train_data = train_data.sample(frac=0.2, random_state=1996)
validation_data = validation_data.sample(frac=0.2, random_state=1996)

# %%
train_data.shape, validation_data.shape, test_data.shape

# %%
train_data.to_csv("../Data/sampled_data/sampled_train_data.csv.gz", sep=',', index=False, compression='gzip')
validation_data.to_csv("../Data/sampled_data/sampled_validation_data.csv.gz", sep=',', index=False, compression='gzip')
